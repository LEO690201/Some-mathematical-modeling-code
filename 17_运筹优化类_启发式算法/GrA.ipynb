# %%
# 贪心算法

from util import *

with open("points.json","r") as f:
    txt=f.readline()
points=json.loads(txt)

N=len(points)

ans=greedy(2,points)
print(ans)
print(calc(ans,points))

plot_ans(ans,points)
# Out:
# [2, 5, 0, 8, 9, 7, 6, 4, 3, 1]
# 330.9340479494346
